# %% [markdown]
# <a href="https://colab.research.google.com/github/jenialves/P.A-1-C-grupo-A/blob/main/vari%C3%A1veis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# variáveis

# %%
# tipos numéricos
idade = 15 # int
altura = 1.55 # float
número_complexo = 2 + 3j # complex

# tipo texto
nome = "jeniffer" #str

# tipo booleano
esta_chovendo = False # bool
