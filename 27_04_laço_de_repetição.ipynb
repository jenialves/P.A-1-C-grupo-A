# %% [markdown]
# <a href="https://colab.research.google.com/github/jenialves/P.A-1-C-grupo-A/blob/main/27_04_la%C3%A7o_de_repeti%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# interações e laços de repetição

# %%
print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
# Out:
# Olá mundo!
# Olá mundo!
# Olá mundo!
# Olá mundo!
# Olá mundo!

# %%
for i in range (5):
  print ("Olá mundo!")
# Out:
# Olá mundo!
# Olá mundo!
# Olá mundo!
# Olá mundo!
# Olá mundo!

# %%
for i in range (6):
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range (1, 6):
  print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# escrever um programa que imprime de 5 até 0

for i in range (6):
  print  (5 - i)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
# escrever um programa que imprime os números pares de 0 a 10

for i in range (11):

  if i % 2 == 0:
   print (i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
# escrever um programa que imprime os números pares de 0 a 10

for i in range (0, 11, 2):
  print (i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
# números ímpares

for i in range (1, 11, 2):
  print (i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# escrever um programa que o usuário digita um número de 1 a 10 e imprime a tabuada

número = int (input("digite um número: "))
for i in range (0, 11):
  print (f"{número} x {i} = {número * i}")
# Out:
# digite um número: 3
# 3 x 0 = 0
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
