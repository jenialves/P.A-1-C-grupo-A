# %% [markdown]
# <a href="https://colab.research.google.com/github/jenialves/P.A-1-C-grupo-A/blob/main/25_05_la%C3%A7os_de_intera%C3%A7%C3%A3o_while.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# laços e interações - "While"

senha = " "

while senha != 1234:

  senha = int (input("digite sua senha: "))
# Out:
# digite sua senha: 20
# digite sua senha: 154
# digite sua senha: 250
# digite sua senha: 1234

# %%
# Contagem de 0 até 5:

for i in range (6):
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
contador = 5

while contador >= 0:
  print (contador)
  contador -=1
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
# calculadora simples - escrever um programa que calcula as 04 operações matemáticas

# opção 1 - somar
# opção 2 - subtrair
# opção 3 - multiplicar
# opção 4 - dividir
# opção 5 - sair

opção = " "
a = 0
b = 0

print ("--------- MENU ---------")
print (" ")

print ("opção 1 - somar")
print ("opção 2 - subtrair")
print ("opção 3 - multiplicar")
print ("opção 4 - dividir")
print ("opção 5 - sair")
print ("====================")
print (" ")

try:

  while opção != 5:
    opção = int (input("digite a opção desejada ou 5 para sair: "))

    if opção <= 0 or opção >= 6:
      print ("digite uma opção de 1 a 4 ou 5 para sair!")

    elif opção == 1:
      a = float (input("digite o primeiro número: "))
      b = float (input("digite o segundo número: "))

      print(f"total da soma de {a} + {b} é igual: {a + b}")
      print(" ")

    elif opção == 2:
      a = float (input("digite o primeiro número: "))
      b = float (input("digite o segundo número: "))

      print(f"total da subtração de {a} - {b} é igual: {a - b}")
      print(" ")

    elif opção == 3:
      a = float (input("digite o primeiro número: "))
      b = float (input("digite o segundo número: "))

      print(f"total da multiplicação de {a} * {b} é igual: {a * b}")
      print(" ")

    elif opção == 4:
      a = float (input("digite o primeiro número: "))
      b = float (input("digite o segundo número: "))

      print(f"total da divisão de {a} / {b} é igual: {a / b}")
      print(" ")

except:
  print("digite apenas números de 01 á 05!")
# Out:
# --------- MENU ---------
#
# opção 1 - somar
# opção 2 - subtrair
# opção 3 - multiplicar
# opção 4 - dividir
# opção 5 - sair
# ...
#
# digite a opção desejada ou 5 para sair: 4
# digite o primeiro número: 6
# digite o segundo número: 3
# total da divisão de 6.0 / 3.0 é igual: 2.0
#
# digite a opção desejada ou 5 para sair: 1
# digite o primeiro número: 10
# digite o segundo número: 20
# total da soma de 10.0 + 20.0 é igual: 30.0
#
# digite a opção desejada ou 5 para sair: 2
# digite o primeiro número: 5
# digite o segundo número: 6
# total da subtração de 5.0 - 6.0 é igual: -1.0
#
# digite a opção desejada ou 5 para sair: 3
# digite o primeiro número: 8
# digite o segundo número: 8
# total da multiplicação de 8.0 * 8.0 é igual: 64.0
#
# digite a opção desejada ou 5 para sair: 5

# %%
# Escrever um programa que recebe 4 notas, calcula a média e imprimi se o aluno foi aprovado, está em recuparação ou reprovado

# nota maior ou igual a 7 - aprovado
# nota maior ou igual a 5 - recuperação
# nota menor que 5 - reprovado

nota1 = float (input("digite a primeira nota: "))
nota2 = float (input("digite a segunda nota: "))
nota3 = float (input("digite a terceira nota: "))
nota4 = float (input("digite a quarta nota: "))

média = (nota1+ nota2 + nota3 + nota4) / 4

if média >= 7:
  print("o aluno foi aprovado")

elif média >= 5:
 print("o aluno está em recuperação")

else:
  print("o aluno foi reprovado")
# Out:
# digite a primeira nota: 10
# digite a segunda nota: 5
# digite a terceira nota: 8
# digite a quarta nota: 2
# o aluno está em recuperação
