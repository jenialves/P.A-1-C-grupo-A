# %% [markdown]
# <a href="https://colab.research.google.com/github/jenialves/P.A-1-C-grupo-A/blob/main/hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercícios aula PA - tipo de dados

# %%
nome = "jeniffer" #str
idade = 15 #int
altura =
